# %% [markdown]
# <a href="https://colab.research.google.com/github/sarenales/Intro_python_basico/blob/main/C4_Herencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Herencia
#
# La herencia es un concepto fundamental en la programación orientada a objetos (POO) que permite crear nuevas clases a partir de clases existentes.
#
# La herencia es un proceso mediante el cual se puede crear una clase **hija** que hereda de una clase **padre**, **compartiendo sus métodos y atributos**. Además de ello, una clase hija puede sobreescribir los métodos o atributos, o incluso definir unos nuevos.
#
# Se puede crear una clase hija con tan solo pasar como parámetro la clase de la que queremos heredar.

# %% [markdown]
# Imagina que estás jugando con bloques de construcción y quieres crear diferentes animales. Puedes hacer un bloque base llamado "Animal" que tiene cosas comunes para todos los animales, como el nombre y el sonido que hacen.

# %% [markdown]
# ## Clase Padre
# Primero, creamos un bloque base llamado "Animal". Este bloque tiene un nombre y una función para hacer sonido.

# %%
class Animal:
    def __init__(self, nombre):
        self.nombre = nombre

    def hacer_sonido(self):
        pass

# %% [markdown]
# ## Clase Hijo
#
# Ahora, queremos hacer bloques más específicos, como "Perro" y "Gato". Ambos son animales, pero hacen sonidos diferentes. Usamos el bloque base "Animal" y agregamos cosas especiales para perros y gatos.

# %%
# Crear un Perro
class Perro(Animal):              # Creamos una clase hija que hereda de la padre
    def hacer_sonido(self):
        return "Guau!"

# %%
# Crear un Gato
class Gato(Animal):
    def hacer_sonido(self):
        return "Miau"

# %% [markdown]
# Ahora que tenemos nuestros bloques, podemos hacer perros y gatos que tengan nombres y hagan sonidos.

# %%
# Crear un perro y un gato
mi_perro = Perro("Rex")
mi_gato = Gato("Luna")

# Mostrar el nombre y el sonido que hacen
print(f"Mi perro {mi_perro.nombre} dice {mi_perro.hacer_sonido()}")
print(f"Mi gato {mi_gato.nombre} dice {mi_gato.hacer_sonido()}")
# Out:
# Mi perro Rex dice Guau!
# Mi gato Luna dice Miau

# %% [markdown]
# **¿Y para que queremos la herencia?** Dado que una clase hija hereda los atributos y métodos de la padre, nos puede ser muy útil cuando tengamos clases que se parecen entre sí pero tienen ciertas particularidades. En este caso en vez de definir un montón de clases para cada animal, podemos tomar los elementos comunes y crear una clase Animal de la que hereden el resto, respetando por tanto la filosofía DRY (Don't Repeat yourself). Realizar estas abstracciones y buscar el denominador común para definir una clase de la que hereden las demás, es una tarea de lo más compleja en el mundo de la programación.

# %% [markdown]
# # Ventajas de la Herencia
#
# * Reutilizar Bloques: No tenemos que volver a escribir las partes comunes (como el nombre) para cada tipo de animal.
# * Facilitar Cambios: Si queremos cambiar algo común para todos los animales, solo cambiamos el bloque base "Animal".
# * Agregar Nuevos Animales: Podemos crear más animales fácilmente, como un "Pájaro" que diga "Pío".

# %% [markdown]
# # Compartiendo y modificando métodos
#
#
# Continuemos con nuestro ejemplo de perros y animales. Vamos a definir una clase padre Animal que tendrá todos los atributos y métodos genéricos que los animales pueden tener. Esta tarea de buscar el denominador común es muy importante en programación. Veamos los atributos:
#
# * Tenemos la especie ya que todos los animales pertenecen a una.
# * Y la edad, ya que todo ser vivo nace, crece, se reproduce y muere.
#
# Y los métodos o funcionalidades:
#
# * Tendremos el método hablar, que cada animal implementará de una forma. Los perros ladran, las abejas zumban y los caballos relinchan.
# * Un método moverse. Unos animales lo harán caminando, otros volando.
# * Y por último un método descríbeme que será común.
#
# Definimos la clase padre, con una serie de atributos comunes para todos los animales como hemos indicado.

# %%
class Animal:
    def __init__(self, especie, edad):
        self.especie = especie
        self.edad = edad

    # Método genérico pero con implementación particular
    def hablar(self):
        # Método vacío
        pass

    # Método genérico pero con implementación particular
    def moverse(self):
        # Método vacío
        pass

    # Método genérico con la misma implementación
    def describeme(self):
        print("Soy un Animal del tipo", type(self).__name__)

# %% [markdown]
# Tenemos ya por lo tanto una clase genérica Animal, que generaliza las características y funcionalidades que todo animal puede tener. Ahora creamos una clase Perro que hereda del Animal. Como primer ejemplo vamos a crear una clase vacía, para ver como los métodos y atributos son heredados por defecto.

# %%
# Perro hereda de Animal
class Perro(Animal):
    pass

mi_perro = Perro('mamífero', 10)
mi_perro.describeme()
mi_perro.hablar()
# Soy un Animal del tipo Perro
# Out:
# Soy un Animal del tipo Perro

# %% [markdown]
# Con tan solo un par de líneas de código, hemos creado una clase nueva que tiene todo el contenido que la clase padre tiene, pero aquí viene lo que es de verdad interesante. Vamos a crear varios animales concretos y sobreescrbir algunos de los métodos que habían sido definidos en la clase Animal, como el hablar o el moverse, ya que cada animal se comporta de una manera distinta.

# %% [markdown]
# Podemos incluso crear nuevos métodos que se añadirán a los ya heredados, como en el caso de la Abeja con picar().

# %%
class Perro(Animal):
    def hablar(self):
        print("Guau!")
    def moverse(self):
        print("Caminando con 4 patas")

class Vaca(Animal):
    def hablar(self):
        print("Muuu!")
    def moverse(self):
        print("Caminando con 4 patas")

class Abeja(Animal):
    def hablar(self):
        print("Bzzzz!")
    def moverse(self):
        print("Volando")
    # Nuevo método
    def picar(self):
        print("Picar!")

# %% [markdown]
# Por lo tanto ya podemos crear nuestros objetos de esos animales y hacer uso de sus métodos que podrían clasificarse en tres:
#
# * Heredados directamente de la clase padre: describeme()
# * Heredados de la clase padre pero modificados: hablar() y moverse()
# * Creados en la clase hija por lo tanto no existentes en la clase padre: picar()

# %%
mi_perro = Perro('mamífero', 10)
mi_vaca = Vaca('mamífero', 23)
mi_abeja = Abeja('insecto', 1)

mi_perro.hablar()
mi_vaca.hablar()
# Guau!
# Muuu!

mi_vaca.describeme()
mi_abeja.describeme()
# Soy un Animal del tipo Vaca
# Soy un Animal del tipo Abeja

mi_abeja.picar()
# Picar!
# Out:
# Guau!
# Muuu!
# Soy un Animal del tipo Vaca
# Soy un Animal del tipo Abeja
# Picar!

# %% [markdown]
# # Ejercicio 1:
#
# Crea una superclase(padre) **Vehiculo_rueda** que tenga un atributo **nombre** y un método **ruido** que no haga nada.
#
# Luego, crea dos subclases(clases hijas) **Coche** y **Bicicleta** que hereden de Vehiculo. Cada subclase debe sobrescribir el método ruido para imprimir un sonido específico.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Vehiculo_rueda:
  def __init__(self,nombre):
    self.nombre = nombre

  def ruido(self):
    pass
#----------------------------------------------------------------------

class Coche(Vehiculo_rueda):
  def ruido(self):
    return "Rum,rum..."

class Bicicleta(Vehiculo_rueda):
  def ruido(self):
    return "Clin,clin"

#----------------------------------------------------------------------

mi_coche = Coche("Lola")
mi_bicicleta = Bicicleta("Carlos")

mi_coche.ruido()
mi_bicicleta.ruido()

print(f"Mi coche {mi_coche.nombre} hace como ruido {mi_coche.ruido()}")
print(f"Mi bicicleta {mi_bicicleta.nombre} hace como ruido {mi_bicicleta.ruido()}")
# Out:
# Mi coche Lola hace como ruido Rum,rum...
# Mi bicicleta Carlos hace como ruido Clin,clin

# %% [markdown]
# # Ejercicio 2
# Añade un atributo **velocidad** a la superclase Vehiculo y un método **mostrar_velocidad** que imprima la velocidad. Luego, crea instancias de Coche y Bicicleta con diferentes velocidades y muestra sus velocidades.

# %%
class Vehiculo:
  def __init__(self,nombre,velocidad):
    self.nombre = nombre
    self.velocidad = velocidad

  def mostrar_velocidad(self):
    pass
#----------------------------------------------------------------------

class Coche(Vehiculo):
  def mostrar_velocidad(self):
    return self.velocidad

class Bicicleta(Vehiculo):
  def mostrar_velocidad(self):
    return self.velocidad

#----------------------------------------------------------------------

mi_coche = Coche("Lola","100km/h")
mi_bicicleta = Bicicleta("Carlos","20km/h")

mi_coche.mostrar_velocidad()
mi_bicicleta.mostrar_velocidad()

print(f"Mi coche {mi_coche.nombre} tiene una velocidad de {mi_coche.mostrar_velocidad()}")
print(f"Mi bicicleta {mi_bicicleta.nombre} tiene una velocidad de {mi_bicicleta.mostrar_velocidad()}")
# Out:
# Mi coche Lola tiene una velocidad de 100km/h
# Mi bicicleta Carlostiene una velocidad de 20km/h
